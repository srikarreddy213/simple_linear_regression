# %% [markdown]
# <a href="https://colab.research.google.com/github/srikarreddy213/simple_linear_regression/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
df = sns.load_dataset('taxis')

df.head()

df.info()

df.shape

df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB
# ...

# %%
df.isna().sum()
((df.shape[0] - df.dropna().shape[0]) / df.shape[0]) * 100
df = df.dropna()
df.shape
num_df = df.select_dtypes(include=['int64','float64'])
num_df.head()
cat_df = df.select_dtypes(include='object')
cat_df.head()
# Out:
#     color      payment            pickup_zone           dropoff_zone  \
# 0  yellow  credit card        Lenox Hill West    UN/Turtle Bay South
# 1  yellow         cash  Upper West Side South  Upper West Side South
# 2  yellow  credit card          Alphabet City           West Village
# 3  yellow  credit card              Hudson Sq         Yorkville West
# 4  yellow  credit card           Midtown East         Yorkville West
#
#   pickup_borough dropoff_borough
# 0      Manhattan       Manhattan
# 1      Manhattan       Manhattan
# 2      Manhattan       Manhattan
# 3      Manhattan       Manhattan
# 4      Manhattan       Manhattan

# %%
pickup = df['pickup']
dropoff = df['dropoff']
passengers = df['passengers']
distance = df['distance']
fare = df['fare']
tip = df['tip']
tolls = df['tolls']
total = df['total']
color = df['color']
payment = df['payment']
pickup_zone = df['pickup_zone']
dropoff_zone = df['dropoff_zone']
pickup_borough = df['pickup_borough']
dropoff_borough = df['dropoff_borough']

# %%
import matplotlib.pyplot as plt
df.color.value_counts()
sns.barplot(x=df.color, y=df.tip, estimator='mean')
plt.show()
sns.barplot(x=df.color, y=df.tip, estimator='std')
plt.show()
sns.histplot(x=df.tip, kde=True, hue=df.color)
plt.show()
yellow_df = df[df['color'] == 'yellow']
green_df = df[df['color'] == 'green']
yellow_df['tip'].mean(), green_df['tip'].mean()
# Out:
# (np.float64(2.1827228736273963), np.float64(0.8069628099173554))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Fix: Ensure df is defined and preprocessed if this cell is run independently
df = sns.load_dataset('taxis')
df = df.dropna()

df.payment.value_counts()

sns.barplot(x=df.payment, y=df.tip, estimator='mean')
plt.xticks(rotation=45)
plt.show()

sns.barplot(x=df.payment, y=df.tip, estimator='std')
plt.xticks(rotation=45)
plt.show()

sns.histplot(x=df.tip, kde=True, hue=df.payment)
plt.show()

credit_df = df[df['payment'] == 'credit card']
cash_df = df[df['payment'] == 'cash']

credit_df['tip'].mean(), cash_df['tip'].mean()
# Out:
# (np.float64(2.751630004399472), np.float64(0.0))

# %%
# =========================
# TIP vs PICKUP BOROUGH
# =========================
sns.barplot(x="pickup_borough", y="tip", data=df, estimator="mean")
plt.show()

sns.histplot(data=df, x="tip", hue="pickup_borough", kde=True)
plt.show()

groups_pickup = [
    df.loc[df["pickup_borough"] == b, "tip"]
    for b in df["pickup_borough"].unique()
]

f_stat, p_val = stats.f_oneway(*groups_pickup)
print("Pickup Borough ANOVA p-value:", p_val)

tukey_pickup = pairwise_tukeyhsd(
    endog=df["tip"],
    groups=df["pickup_borough"],
    alpha=0.05
)
print(tukey_pickup)

# =========================
# TIP vs DROPOFF BOROUGH
# =========================
sns.barplot(x="dropoff_borough", y="tip", data=df, estimator="mean")
plt.show()

sns.histplot(data=df, x="tip", hue="dropoff_borough", kde=True)
plt.show()

groups_dropoff = [
    df.loc[df["dropoff_borough"] == b, "tip"]
    for b in df["dropoff_borough"].unique()
]

f_stat, p_val = stats.f_oneway(*groups_dropoff)
print("Dropoff Borough ANOVA p-value:", p_val)

tukey_dropoff = pairwise_tukeyhsd(
    endog=df["tip"],
    groups=df["dropoff_borough"],
    alpha=0.05
)
print(tukey_dropoff)
# Out:
# Pickup Borough ANOVA p-value: 5.155109332422435e-58
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#   group1    group2  meandiff p-adj lower  upper  reject
# -------------------------------------------------------
#     Bronx  Brooklyn   0.8305 0.008 0.1595 1.5015   True
#     Bronx Manhattan    1.797   0.0  1.194    2.4   True
#     Bronx    Queens   2.9179   0.0 2.2759 3.5599   True
#  Brooklyn Manhattan   0.9665   0.0 0.6499  1.283   True
#  Brooklyn    Queens   2.0873   0.0 1.7016 2.4731   True
# Manhattan    Queens   1.1209   0.0 0.8716 1.3701   True
# -------------------------------------------------------
# Dropoff Borough ANOVA p-value: 5.87859571331583e-26
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#   group1      group2    meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#     Bronx      Brooklyn   1.3869    0.0  0.7691  2.0046   True
# ...

# %%
sns.histplot(df['tip'],kde=True)
plt.show()

# %%
r,p_val = stats.spearmanr(df['tip'],df['passengers'])
print("corelation :",r)
print("p.value : ",p_val)
alpha=0.05
if p_val < alpha:
  print("Reject the null hypothesis")
else:
  print("Fail to reject the null hypothesis")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-928599243.py in <cell line: 0>()
# ----> 1 r,p_val = stats.spearmanr(df['tip'],df['passengers'])
#       2 print("corelation :",r)
#       3 print("p.value : ",p_val)
#       4 alpha=0.05
#       5 if p_val < alpha:
#
# NameError: name 'stats' is not defined
